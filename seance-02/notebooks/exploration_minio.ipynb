# %%
# %pip install pandas boto3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 5.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 5.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import pandas as pd
import io

# Connexion interne au conteneur MinIO
s3 = boto3.client(
    "s3",
    endpoint_url="http://minio:9000",
    aws_access_key_id="anfa-admin",
    aws_secret_access_key="anfa-password-2026"
)

# Lister les fichiers pour vérifier que le bucket 'anfa-raw' est bien là
buckets = s3.list_buckets()
print("Buckets disponibles :", [b['Name'] for b in buckets['Buckets']])

# Lire le fichier bus.csv
obj = s3.get_object(Bucket="anfa-raw", Key="referentiel/bus.csv")
df = pd.read_csv(io.BytesIO(obj['Body'].read()))
df.head()
# Out:
# Buckets disponibles : ['anfa-raw']
#   bus_id immatriculation                modele  capacite ligne_assignee  \
# 0   B001      TG 2951-AD        Toyota Coaster        31            L11
# 1   B002      TG 7891-BC        Toyota Coaster        30            L10
# 2   B003      TG 2322-AB       Yutong ZK6107HA        48            L08
# 3   B004      TG 6148-AC        Hyundai County        30            L06
# 4   B005      TG 9414-BD  Mercedes-Benz Citaro        75            L02
#
#   date_mise_en_service        statut
# 0           2019-04-01         actif
# 1           2025-04-01         actif
# 2           2018-11-01         actif
# 3           2023-07-01  hors_service
# 4           2022-05-01         actif
